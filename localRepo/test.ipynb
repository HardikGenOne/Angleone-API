# %%
from SmartApi import SmartConnect #or from SmartApi.smartConnect import SmartConnect
import pyotp
from logzero import logger

# %%
api_key = 'Xj4eEyco'
username = 'L52128673'
pwd = '7990'
smartApi = SmartConnect(api_key)
# Out:
# [I 250310 20:44:56 smartConnect:121] in pool

# %%
try:
    token = "J4DWDXYMDAKVV6VFJW6RHMS3RI"
    totp = pyotp.TOTP(token).now()
except Exception as e:
    logger.error("Invalid Token: The provided token is not valid.")
    raise e

# %%
correlation_id = "abcde"
data = smartApi.generateSession(username, pwd, totp)

# %%
if data['status'] == False:
    logger.error(data)
    
else:
    # login api call
    # logger.info(f"You Credentials: {data}")
    authToken = data['data']['jwtToken']
    refreshToken = data['data']['refreshToken']
    # fetch the feedtoken
    feedToken = smartApi.getfeedToken()
    # fetch User Profile
    res = smartApi.getProfile(refreshToken)
    smartApi.generateToken(refreshToken)
    res1=res['data']['exchanges']

# %%
try:
    historicParam={
    "exchange": "NSE",
    "symboltoken": "3045",
    "interval": "ONE_HOUR",
    "fromdate": "2015-02-08 09:00", 
    "todate": "2025-02-08 09:16"
    }
    hist = smartApi.getCandleData(historicParam)

except Exception as e:
    logger.exception(f"Logout failed: {e}")

# %%
hist["data"]
# Out:
# [['2024-01-05T10:15:00+05:30', 650.0, 651.75, 646.4, 648.35, 2466190],
#  ['2024-01-05T11:15:00+05:30', 648.35, 648.55, 644.75, 645.75, 1366665],
#  ['2024-01-05T12:15:00+05:30', 645.75, 646.75, 643.5, 644.25, 1118911],
#  ['2024-01-05T13:15:00+05:30', 644.2, 644.55, 639.2, 639.75, 2212031],
#  ['2024-01-05T14:15:00+05:30', 639.75, 644.2, 637.9, 641.65, 4005708],
#  ['2024-01-05T15:15:00+05:30', 641.6, 641.9, 640.0, 641.45, 747677],
#  ['2024-01-08T09:15:00+05:30', 640.0, 644.95, 636.65, 639.55, 2622707],
#  ['2024-01-08T10:15:00+05:30', 639.4, 640.2, 637.0, 638.2, 1439810],
#  ['2024-01-08T11:15:00+05:30', 638.2, 638.6, 632.75, 634.35, 1845632],
#  ['2024-01-08T12:15:00+05:30', 634.25, 635.8, 633.3, 633.8, 1273056],
#  ['2024-01-08T13:15:00+05:30', 633.8, 635.7, 632.75, 633.7, 1817327],
#  ['2024-01-08T14:15:00+05:30', 633.7, 633.95, 625.5, 625.95, 4323318],
#  ['2024-01-08T15:15:00+05:30', 625.95, 628.0, 625.15, 627.9, 1350853],
# ...

# %%
from runTest import AngleOne_Smart_API

api_key = "Xj4eEyco"
username = "L52128673"
pwd = "7990"
token = "J4DWDXYMDAKVV6VFJW6RHMS3RI"
instance = AngleOne_Smart_API(api_key,username,pwd,token)

instance.connect()
# instance.login()
# Out:
# [I 250310 21:28:49 smartConnect:121] in pool
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'clientcode': 'L52128673', 'name': 'LOKESH MAHESHWARI', 'email': '', 'mobileno': '', 'exchanges': ['nse_fo', 'nse_cm', 'cde_fo', 'ncx_fo', 'bse_fo', 'bse_cm', 'mcx_fo'], 'products': ['MARGIN', 'MIS', 'NRML', 'CNC', 'CO', 'BO'], 'lastlogintime': '', 'broker': '', 'jwtToken': 'Bearer eyJhbGciOiJIUzUxMiJ9.....VxCW4KBB6PAttI9gaOfIeQot--AqOPL6WQ0e6xM-XwrHJwVxUhKeNNHgYYhqF4Lu4KNgyLKfDEmup-eFO2OWxw', 'refreshToken': 'eyJhbGciOiJIUzUxMiJ9.....ceC7DS-bbTaih-MSQXVxP-vFpweVrKqsiyTu5FvUSLICIbWBFhSTFPYi5yHy481uism3JCM62IufbQPUlJrk0A', 'feedToken': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Ikw1MjEyODY3MyIsImlhdCI6MTc0MTYyMjMyOSwiZXhwIjoxNzQxNzA4NzI5fQ.XmN5uL55lcWm48etuM6IlvM8Inzzok2mLCIYAKMFr-4aWhjAxoUOeyrDOWYGZQqDp6Zau8hcIazCr4oOS5AYeQ'}}

# %%
from AngleSmartAPI import AngleOne_Smart_API
import pandas as pd
api_key = "Xj4eEyco"
username = "L52128673"
pwd = "7990"
token = "J4DWDXYMDAKVV6VFJW6RHMS3RI"
instance = AngleOne_Smart_API(api_key,username,pwd,token)

instance.connect()
data = instance.get_data("NSE","SBIN-EQ","ONE_HOUR","2025-01-01","2025-01-10")
print(data)
# Out:
# [I 250310 22:54:22 smartConnect:121] in pool
# Successfully Connected 🟢
# [I 250310 22:54:22 smartConnect:485] Search successful. Found 1 trading symbols for the given query:
#     1. exchange: NSE, tradingsymbol: SBIN-EQ, symboltoken: 3045
# Got Resources and Exchange Available 🙌🏻
#           Date    Open    High     Low   Close   Volume
# 0   2025-01-01  795.60  798.00  789.50  792.50  1060514
# 1   2025-01-01  792.50  796.30  791.05  796.15  1547147
# 2   2025-01-01  796.15  797.25  792.25  793.30   990923
# 3   2025-01-01  793.25  795.25  791.60  792.10   746895
# 4   2025-01-01  791.85  798.65  791.55  795.25  1140008
# 5   2025-01-01  795.45  795.95  792.15  793.30  1178794
# 6   2025-01-01  793.35  794.40  792.90  794.30   595397
# 7   2025-01-02  795.05  797.40  790.15  790.20  1283670
# 8   2025-01-02  790.35  792.65  790.10  792.35   892390
# 9   2025-01-02  792.35  793.05  787.00  787.85  1468190
# 10  2025-01-02  787.85  795.95  787.30  795.10  2120100
# ...
